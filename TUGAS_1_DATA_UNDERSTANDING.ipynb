# %% [markdown]
# <a href="https://colab.research.google.com/github/katrinaaghta/Machine-Learning-/blob/main/TUGAS_1_DATA_UNDERSTANDING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# KATRINA AGHATA SURA' H081221041
# PEMBELAJARA MESIN
# DATA UNDERSTANDING

# %%
import pandas as pd
dataset = '/content/drive/MyDrive/imbd_dataset/imdb_data.csv'
data = pd.read_csv(dataset)
data
# Out:
#              id                          primaryTitle  \
# 0     tt0035423                        Kate & Leopold
# 1     tt0065421                        The Aristocats
# 2     tt0065938                        Kelly's Heroes
# 3     tt0066026                               M*A*S*H
# 4     tt0066206                                Patton
# ...         ...                                   ...
# 3343  tt9770150                             Nomadland
# 3344  tt9777666                      The Tomorrow War
# 3345  tt9784798           Judas and the Black Messiah
# 3346  tt9844522  Escape Room: Tournament of Champions
# 3347  tt9893250                          I Care a Lot
#
#                              originalTitle  isAdult  runtimeMinutes  \
# 0                           Kate & Leopold        0             118
# 1                           The AristoCats        0              78
# 2                           Kelly's Heroes        0             144
# ...

# %%
data.head()
# Out:
#           id    primaryTitle   originalTitle  isAdult  runtimeMinutes  \
# 0  tt0035423  Kate & Leopold  Kate & Leopold        0             118
# 1  tt0065421  The Aristocats  The AristoCats        0              78
# 2  tt0065938  Kelly's Heroes  Kelly's Heroes        0             144
# 3  tt0066026         M*A*S*H         M*A*S*H        0             116
# 4  tt0066206          Patton          Patton        0             172
#
#                        genres  averageRating  numVotes    budget       gross  \
# 0      Comedy,Fantasy,Romance            6.4     87925  48000000  76019048.0
# 1  Adventure,Animation,Comedy            7.1    111758   4000000  35459543.0
# 2        Adventure,Comedy,War            7.6     52628   4000000   5200000.0
# 3            Comedy,Drama,War            7.4     75784   3500000  81600000.0
# 4         Biography,Drama,War            7.9    106476  12000000  61749765.0
#
#         release_date              directors
# ...

# %%
print(data.dtypes)
# Out:
# id                 object
# primaryTitle       object
# originalTitle      object
# isAdult             int64
# runtimeMinutes      int64
# genres             object
# averageRating     float64
# numVotes            int64
# budget              int64
# gross             float64
# release_date       object
# directors          object
# dtype: object

# %%
datanoid = data.drop(data.columns[0],axis=1)
datanoid
# Out:
#                               primaryTitle  \
# 0                           Kate & Leopold
# 1                           The Aristocats
# 2                           Kelly's Heroes
# 3                                  M*A*S*H
# 4                                   Patton
# ...                                    ...
# 3343                             Nomadland
# 3344                      The Tomorrow War
# 3345           Judas and the Black Messiah
# 3346  Escape Room: Tournament of Champions
# 3347                          I Care a Lot
#
#                              originalTitle  isAdult  runtimeMinutes  \
# 0                           Kate & Leopold        0             118
# 1                           The AristoCats        0              78
# 2                           Kelly's Heroes        0             144
# 3                                  M*A*S*H        0             116
# 4                                   Patton        0             172
# ...

# %%
data.describe()
# Out:
#        isAdult  runtimeMinutes  averageRating      numVotes        budget  \
# count   3348.0     3348.000000     3348.00000  3.348000e+03  3.348000e+03
# mean       0.0      112.739845        6.73853  2.155492e+05  5.039280e+07
# std        0.0       19.927703        0.88221  2.480211e+05  5.178614e+07
# min        0.0       63.000000        1.00000  5.000400e+04  1.800000e+01
# 25%        0.0       98.000000        6.20000  7.897700e+04  1.500000e+07
# 50%        0.0      109.000000        6.80000  1.290400e+05  3.200000e+07
# 75%        0.0      124.000000        7.30000  2.468495e+05  6.800000e+07
# max        0.0      242.000000        9.30000  2.817283e+06  3.560000e+08
#
#               gross
# count  3.297000e+03
# mean   1.681599e+08
# std    2.366507e+08
# min    2.100000e+02
# 25%    3.623022e+07
# 50%    8.821516e+07
# 75%    2.008117e+08
# max    2.923706e+09

# %%
data.loc[:,"runtimeMinutes":].corr()
# Out:
# <ipython-input-21-3965d8e43b6e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.loc[:,"runtimeMinutes":].corr()
#                 runtimeMinutes  averageRating  numVotes    budget     gross
# runtimeMinutes        1.000000       0.359969  0.333702  0.309109  0.253860
# averageRating         0.359969       1.000000  0.484695 -0.079510  0.127964
# numVotes              0.333702       0.484695  1.000000  0.306588  0.521585
# budget                0.309109      -0.079510  0.306588  1.000000  0.698397
# gross                 0.253860       0.127964  0.521585  0.698397  1.000000

# %%
# @title runtimeMinutes vs averageRating

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='averageRating', y='runtimeMinutes', s=20, alpha=.4)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-fbd9a210-4ddb-439b-8d0c-43d9ad43f568" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fbd9a210-4ddb-439b-8d0c-43d9ad43f568">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "IMDB Dataset 2023"
# Out:
# ...
# ref                                                  title                                          size  lastUpdated          downloadCount  voteCount  usabilityRating
# ---------------------------------------------------  --------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# kianindeed/imdb-movie-dataset-dec-2023               IMDB Movie Dataset Till Dec-2023              106KB  2024-01-08 02:30:06           1662         38  0.9411765
# adriankiezun/imdb-dataset-2023                       IMDB Dataset 2023                             153KB  2024-02-29 11:26:40            107          9  1.0
# komalkhetlani/imdb-dataset                           IMDb Dataset - From 1888 to 2023              116MB  2021-04-05 08:05:24           2621         56  0.9411765
# sanjeetsinghnaik/top-1000-highest-grossing-movies    Top 1000 Highest Grossing Movies              124KB  2023-09-25 20:40:24          12927        219  1.0
# ...

# %%
# !kaggle datasets download adriankiezun/imdb-dataset-2023
# Out:
# ...
# 100% 153k/153k [00:00<00:00, 291kB/s]
# 100% 153k/153k [00:00<00:00, 291kB/s]

# %%
# !unzip /content/imdb-dataset-2023.zip
# Out:
# Archive:  /content/imdb-dataset-2023.zip
# replace imdb_data.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: imdb_data.csv

# %%
import pandas as pd
data = pd.read_csv('/content/imdb_data.csv')
data
# Out:
#              id                          primaryTitle  \
# 0     tt0035423                        Kate & Leopold
# 1     tt0065421                        The Aristocats
# 2     tt0065938                        Kelly's Heroes
# 3     tt0066026                               M*A*S*H
# 4     tt0066206                                Patton
# ...         ...                                   ...
# 3343  tt9770150                             Nomadland
# 3344  tt9777666                      The Tomorrow War
# 3345  tt9784798           Judas and the Black Messiah
# 3346  tt9844522  Escape Room: Tournament of Champions
# 3347  tt9893250                          I Care a Lot
#
#                              originalTitle  isAdult  runtimeMinutes  \
# 0                           Kate & Leopold        0             118
# 1                           The AristoCats        0              78
# 2                           Kelly's Heroes        0             144
# ...
